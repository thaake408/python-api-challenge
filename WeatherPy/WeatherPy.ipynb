# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 577

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=metric'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | bardai
# Processing Record 3 of Set 1 | vilyuchinsk
# Processing Record 4 of Set 1 | qaqortoq
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | concepcion
# Processing Record 7 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | tura
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | impfondo
# Processing Record 12 of Set 1 | san luis
# Processing Record 13 of Set 1 | whitehorse
# Processing Record 14 of Set 1 | altai
# Processing Record 15 of Set 1 | nemuro
# Processing Record 16 of Set 1 | atafu village
# Processing Record 17 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 18 of Set 1 | shakawe
# Processing Record 19 of Set 1 | kailua-kona
# Processing Record 20 of Set 1 | weno
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | siasi
# Processing Record 23 of Set 1 | dunedin
# Processing Record 24 of Set 1 | mejit
# Processing Record 25 of Set 1 | lerwick
# Processing Record 26 of Set 1 | opuwo
# Processing Record 27 of Set 1 | bilibino
# Processing Record 28 of Set 1 | stanley
# Processing Record 29 of Set 1 | makarov
# Processing Record 30 of Set 1 | talnakh
# Processing Record 31 of Set 1 | maryville
# Processing Record 32 of Set 1 | porto murtinho
# Processing Record 33 of Set 1 | utrik
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | wesselsbron
# Processing Record 36 of Set 1 | ta`u
# Processing Record 37 of Set 1 | choyr
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | luganville
# Processing Record 40 of Set 1 | grytviken
# Processing Record 41 of Set 1 | saint-louis
# Processing Record 42 of Set 1 | hawaiian paradise park
# Processing Record 43 of Set 1 | port mathurin
# Processing Record 44 of Set 1 | brady
# Processing Record 45 of Set 1 | vila franca do campo
# Processing Record 46 of Set 1 | invercargill
# Processing Record 47 of Set 1 | verdal
# Processing Record 48 of Set 1 | barra do garcas
# Processing Record 49 of Set 1 | aasiaat
# Processing Record 50 of Set 1 | severo-yeniseyskiy
# Processing Record 0 of Set 2 | nuuk
# Processing Record 1 of Set 2 | olonkinbyen
# Processing Record 2 of Set 2 | mount gambier
# Processing Record 3 of Set 2 | adamstown
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | prince rupert
# Processing Record 6 of Set 2 | tazovsky
# Processing Record 7 of Set 2 | tosontsengel
# Processing Record 8 of Set 2 | sirte
# Processing Record 9 of Set 2 | phalaborwa
# Processing Record 10 of Set 2 | puerto natales
# Processing Record 11 of Set 2 | iqaluit
# Processing Record 12 of Set 2 | tidjikja
# Processing Record 13 of Set 2 | egilsstadir
# Processing Record 14 of Set 2 | beacon square
# Processing Record 15 of Set 2 | longyearbyen
# Processing Record 16 of Set 2 | isafjordur
# Processing Record 17 of Set 2 | acarau
# Processing Record 18 of Set 2 | port-cartier
# Processing Record 19 of Set 2 | nyurba
# Processing Record 20 of Set 2 | west island
# Processing Record 21 of Set 2 | porto novo
# Processing Record 22 of Set 2 | fortuna
# Processing Record 23 of Set 2 | papatowai
# Processing Record 24 of Set 2 | luderitz
# Processing Record 25 of Set 2 | shubarshi
# Processing Record 26 of Set 2 | waitangi
# Processing Record 27 of Set 2 | bandarbeyla
# Processing Record 28 of Set 2 | kendari
# Processing Record 29 of Set 2 | tofol
# Processing Record 30 of Set 2 | ji'an
# Processing Record 31 of Set 2 | kodiak
# Processing Record 32 of Set 2 | al jahra'
# Processing Record 33 of Set 2 | solnechnyy
# Processing Record 34 of Set 2 | margaret river
# Processing Record 35 of Set 2 | las cruces
# Processing Record 36 of Set 2 | sandnessjoen
# Processing Record 37 of Set 2 | lorengau
# Processing Record 38 of Set 2 | kerikeri
# Processing Record 39 of Set 2 | tuy hoa
# Processing Record 40 of Set 2 | yallahs
# Processing Record 41 of Set 2 | rawson
# Processing Record 42 of Set 2 | paita
# Processing Record 43 of Set 2 | edinburgh of the seven seas
# Processing Record 44 of Set 2 | osilnica
# Processing Record 45 of Set 2 | cooma
# Processing Record 46 of Set 2 | kapuskasing
# Processing Record 47 of Set 2 | maragogi
# Processing Record 48 of Set 2 | midvagur
# Processing Record 49 of Set 2 | guane
# Processing Record 0 of Set 3 | badger
# Processing Record 1 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 2 of Set 3 | albany
# Processing Record 3 of Set 3 | bac lieu
# Processing Record 4 of Set 3 | ilulissat
# Processing Record 5 of Set 3 | constantia
# Processing Record 6 of Set 3 | prosser
# Processing Record 7 of Set 3 | melchor de mencos
# Processing Record 8 of Set 3 | klyuchi
# Processing Record 9 of Set 3 | enterprise
# Processing Record 10 of Set 3 | namibe
# Processing Record 11 of Set 3 | tarnogskiy gorodok
# Processing Record 12 of Set 3 | arica
# Processing Record 13 of Set 3 | toga village
# City not found. Skipping...
# Processing Record 14 of Set 3 | shamakhi
# Processing Record 15 of Set 3 | mina clavero
# Processing Record 16 of Set 3 | pionerskiy
# Processing Record 17 of Set 3 | salekhard
# Processing Record 18 of Set 3 | lihue
# Processing Record 19 of Set 3 | monywa
# Processing Record 20 of Set 3 | portland
# Processing Record 21 of Set 3 | puerto baquerizo moreno
# Processing Record 22 of Set 3 | kenai
# Processing Record 23 of Set 3 | sanctuary point
# Processing Record 24 of Set 3 | ribeira grande
# Processing Record 25 of Set 3 | carnarvon
# Processing Record 26 of Set 3 | blackmans bay
# Processing Record 27 of Set 3 | westport
# Processing Record 28 of Set 3 | san patricio
# Processing Record 29 of Set 3 | hermanus
# Processing Record 30 of Set 3 | conduaga
# Processing Record 31 of Set 3 | arraial do cabo
# Processing Record 32 of Set 3 | palmer
# Processing Record 33 of Set 3 | smithers
# Processing Record 34 of Set 3 | new norfolk
# Processing Record 35 of Set 3 | haridwar
# Processing Record 36 of Set 3 | fale old settlement
# Processing Record 37 of Set 3 | ende
# Processing Record 38 of Set 3 | galesong
# Processing Record 39 of Set 3 | puerto ayora
# Processing Record 40 of Set 3 | vorgashor
# Processing Record 41 of Set 3 | karaman
# Processing Record 42 of Set 3 | morshansk
# Processing Record 43 of Set 3 | taoudenni
# Processing Record 44 of Set 3 | waspan
# Processing Record 45 of Set 3 | mpika
# Processing Record 46 of Set 3 | fougamou
# Processing Record 47 of Set 3 | phan rang-thap cham
# Processing Record 48 of Set 3 | masterton
# Processing Record 49 of Set 3 | saipan
# Processing Record 0 of Set 4 | udachny
# Processing Record 1 of Set 4 | dudinka
# Processing Record 2 of Set 4 | minas de matahambre
# City not found. Skipping...
# Processing Record 3 of Set 4 | paracuru
# Processing Record 4 of Set 4 | bikenibeu village
# Processing Record 5 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 6 of Set 4 | miyanoura
# City not found. Skipping...
# Processing Record 7 of Set 4 | fauske
# Processing Record 8 of Set 4 | bonthe
# Processing Record 9 of Set 4 | dryden
# Processing Record 10 of Set 4 | minas de marcona
# Processing Record 11 of Set 4 | devinuwara
# City not found. Skipping...
# Processing Record 12 of Set 4 | castillos
# Processing Record 13 of Set 4 | seogwipo
# City not found. Skipping...
# Processing Record 14 of Set 4 | port shepstone
# Processing Record 15 of Set 4 | wailua homesteads
# Processing Record 16 of Set 4 | arawa
# Processing Record 17 of Set 4 | manali
# Processing Record 18 of Set 4 | kavaratti
# Processing Record 19 of Set 4 | bredasdorp
# Processing Record 20 of Set 4 | nova sintra
# Processing Record 21 of Set 4 | chonchi
# Processing Record 22 of Set 4 | lompoc
# Processing Record 23 of Set 4 | chimore
# Processing Record 24 of Set 4 | hasaki
# Processing Record 25 of Set 4 | jamestown
# Processing Record 26 of Set 4 | kota belud
# Processing Record 27 of Set 4 | matozinhos
# Processing Record 28 of Set 4 | tolanaro
# Processing Record 29 of Set 4 | kalaleh
# Processing Record 30 of Set 4 | belgrade
# Processing Record 31 of Set 4 | tiksi
# Processing Record 32 of Set 4 | cidreira
# Processing Record 33 of Set 4 | pontian kechil
# Processing Record 34 of Set 4 | kill devil hills
# Processing Record 35 of Set 4 | san antonio de pale
# Processing Record 36 of Set 4 | eyl
# Processing Record 37 of Set 4 | dzhalil'
# Processing Record 38 of Set 4 | okhotsk
# Processing Record 39 of Set 4 | cabedelo
# Processing Record 40 of Set 4 | tommot
# Processing Record 41 of Set 4 | plastun
# Processing Record 42 of Set 4 | al muwayh
# Processing Record 43 of Set 4 | kununurra
# Processing Record 44 of Set 4 | kuruman
# Processing Record 45 of Set 4 | sao paulo de olivenca
# Processing Record 46 of Set 4 | comodoro rivadavia
# Processing Record 47 of Set 4 | ordynskoye
# Processing Record 48 of Set 4 | ulcinj
# Processing Record 49 of Set 4 | la passe
# Processing Record 0 of Set 5 | chiredzi
# Processing Record 1 of Set 5 | lebu
# Processing Record 2 of Set 5 | buala
# Processing Record 3 of Set 5 | chagoda
# Processing Record 4 of Set 5 | victorica
# Processing Record 5 of Set 5 | mili
# Processing Record 6 of Set 5 | akom ii
# Processing Record 7 of Set 5 | saldanha
# Processing Record 8 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 9 of Set 5 | san andros
# City not found. Skipping...
# Processing Record 10 of Set 5 | kruisfontein
# Processing Record 11 of Set 5 | mitu
# Processing Record 12 of Set 5 | norton shores
# Processing Record 13 of Set 5 | tobi village
# City not found. Skipping...
# Processing Record 14 of Set 5 | mumbwa
# Processing Record 15 of Set 5 | sudak
# Processing Record 16 of Set 5 | east london
# Processing Record 17 of Set 5 | tinghir
# Processing Record 18 of Set 5 | pontianak
# Processing Record 19 of Set 5 | akrehamn
# Processing Record 20 of Set 5 | konarka
# Processing Record 21 of Set 5 | geraldton
# Processing Record 22 of Set 5 | pouzauges
# Processing Record 23 of Set 5 | pisco
# Processing Record 24 of Set 5 | flying fish cove
# Processing Record 25 of Set 5 | totness
# Processing Record 26 of Set 5 | robertsport
# Processing Record 27 of Set 5 | peniche
# Processing Record 28 of Set 5 | sur
# Processing Record 29 of Set 5 | gering
# Processing Record 30 of Set 5 | sitka
# Processing Record 31 of Set 5 | nadi
# Processing Record 32 of Set 5 | maba
# Processing Record 33 of Set 5 | haiku-pauwela
# Processing Record 34 of Set 5 | duong dong
# Processing Record 35 of Set 5 | anadyr
# Processing Record 36 of Set 5 | petukhovo
# Processing Record 37 of Set 5 | ola
# Processing Record 38 of Set 5 | coron
# Processing Record 39 of Set 5 | armacao de buzios
# Processing Record 40 of Set 5 | olyokminsk
# Processing Record 41 of Set 5 | nichinan
# Processing Record 42 of Set 5 | touros
# Processing Record 43 of Set 5 | sitia
# Processing Record 44 of Set 5 | yangambi
# Processing Record 45 of Set 5 | posto fiscal rolim de moura
# Processing Record 46 of Set 5 | mhamid
# Processing Record 47 of Set 5 | kuching
# Processing Record 48 of Set 5 | sao joao da barra
# Processing Record 49 of Set 5 | ardakan
# Processing Record 0 of Set 6 | rosetta
# Processing Record 1 of Set 6 | bafoulabe
# Processing Record 2 of Set 6 | ust-tsilma
# Processing Record 3 of Set 6 | al ghayzah
# Processing Record 4 of Set 6 | dyurtyuli
# Processing Record 5 of Set 6 | jieshi
# Processing Record 6 of Set 6 | sidi khaled
# Processing Record 7 of Set 6 | hadibu
# Processing Record 8 of Set 6 | yarmouth
# Processing Record 9 of Set 6 | langtang
# Processing Record 10 of Set 6 | el sauzal de rodriguez
# Processing Record 11 of Set 6 | mantua
# Processing Record 12 of Set 6 | maracacume
# Processing Record 13 of Set 6 | yaren
# Processing Record 14 of Set 6 | lata
# Processing Record 15 of Set 6 | olbia
# Processing Record 16 of Set 6 | cockburn town
# Processing Record 17 of Set 6 | vila velha
# Processing Record 18 of Set 6 | xiva
# Processing Record 19 of Set 6 | ukata
# Processing Record 20 of Set 6 | enewetak
# Processing Record 21 of Set 6 | montelibano
# Processing Record 22 of Set 6 | hami
# Processing Record 23 of Set 6 | kathwana
# City not found. Skipping...
# Processing Record 24 of Set 6 | ust-nera
# Processing Record 25 of Set 6 | batam
# City not found. Skipping...
# Processing Record 26 of Set 6 | praia da vitoria
# Processing Record 27 of Set 6 | remire-montjoly
# Processing Record 28 of Set 6 | kaynarca
# Processing Record 29 of Set 6 | brookings
# Processing Record 30 of Set 6 | barguzin
# Processing Record 31 of Set 6 | codrington
# Processing Record 32 of Set 6 | iskateley
# Processing Record 33 of Set 6 | shiguai
# Processing Record 34 of Set 6 | harda khas
# Processing Record 35 of Set 6 | allada
# Processing Record 36 of Set 6 | selfoss
# Processing Record 37 of Set 6 | arno
# Processing Record 38 of Set 6 | sittwe
# Processing Record 39 of Set 6 | alice springs
# Processing Record 40 of Set 6 | kimbe
# Processing Record 41 of Set 6 | greenville
# Processing Record 42 of Set 6 | antsiranana
# Processing Record 43 of Set 6 | porto-vecchio
# Processing Record 44 of Set 6 | espargos
# City not found. Skipping...
# Processing Record 45 of Set 6 | gokwe
# Processing Record 46 of Set 6 | waeng
# Processing Record 47 of Set 6 | vallenar
# Processing Record 48 of Set 6 | karratha
# Processing Record 49 of Set 6 | krasnoufimsk
# Processing Record 0 of Set 7 | sinabang
# Processing Record 1 of Set 7 | nikolayevsk-on-amure
# Processing Record 2 of Set 7 | kiunga
# Processing Record 3 of Set 7 | hundested
# Processing Record 4 of Set 7 | novodvinsk
# Processing Record 5 of Set 7 | roxas
# Processing Record 6 of Set 7 | kingston
# Processing Record 7 of Set 7 | yangor
# City not found. Skipping...
# Processing Record 8 of Set 7 | isle of lewis
# City not found. Skipping...
# Processing Record 9 of Set 7 | shiyan
# Processing Record 10 of Set 7 | nelson bay
# Processing Record 11 of Set 7 | shingu
# Processing Record 12 of Set 7 | papao
# Processing Record 13 of Set 7 | thunder bay
# Processing Record 14 of Set 7 | broome
# Processing Record 15 of Set 7 | kairouan
# Processing Record 16 of Set 7 | ratnagiri
# Processing Record 17 of Set 7 | kidal
# Processing Record 18 of Set 7 | mirny
# Processing Record 19 of Set 7 | calipatria
# Processing Record 20 of Set 7 | rangia
# Processing Record 21 of Set 7 | port elizabeth
# Processing Record 22 of Set 7 | malango
# Processing Record 23 of Set 7 | belyy yar
# Processing Record 24 of Set 7 | amahai
# Processing Record 25 of Set 7 | coquimbo
# Processing Record 26 of Set 7 | st. john's
# Processing Record 27 of Set 7 | lubsko
# Processing Record 28 of Set 7 | afaahiti
# Processing Record 29 of Set 7 | namtsy
# Processing Record 30 of Set 7 | bovalino
# Processing Record 31 of Set 7 | beihai
# Processing Record 32 of Set 7 | avarua
# Processing Record 33 of Set 7 | college
# Processing Record 34 of Set 7 | cabo san lucas
# Processing Record 35 of Set 7 | ulaangom
# Processing Record 36 of Set 7 | ijuw
# City not found. Skipping...
# Processing Record 37 of Set 7 | houghton
# Processing Record 38 of Set 7 | huautla de jimenez
# Processing Record 39 of Set 7 | tabou
# Processing Record 40 of Set 7 | guerrero negro
# Processing Record 41 of Set 7 | luoyang
# Processing Record 42 of Set 7 | huron
# Processing Record 43 of Set 7 | santa rosa del sara
# City not found. Skipping...
# Processing Record 44 of Set 7 | nibley
# Processing Record 45 of Set 7 | betio village
# Processing Record 46 of Set 7 | atherton
# Processing Record 47 of Set 7 | mokhsogollokh
# Processing Record 48 of Set 7 | pacific grove
# Processing Record 49 of Set 7 | kodinsk
# Processing Record 0 of Set 8 | timimoun
# Processing Record 1 of Set 8 | usogorsk
# Processing Record 2 of Set 8 | stellenbosch
# Processing Record 3 of Set 8 | birao
# Processing Record 4 of Set 8 | labuan bajo
# Processing Record 5 of Set 8 | kurayoshi
# Processing Record 6 of Set 8 | dera ghazi khan
# Processing Record 7 of Set 8 | yuzhno-kurilsk
# Processing Record 8 of Set 8 | wuyang
# Processing Record 9 of Set 8 | al jaradiyah
# Processing Record 10 of Set 8 | lagos
# Processing Record 11 of Set 8 | happy valley-goose bay
# Processing Record 12 of Set 8 | marka
# Processing Record 13 of Set 8 | vernon
# Processing Record 14 of Set 8 | ca mau
# Processing Record 15 of Set 8 | rakops
# Processing Record 16 of Set 8 | wajir
# Processing Record 17 of Set 8 | sari
# Processing Record 18 of Set 8 | al mindak
# Processing Record 19 of Set 8 | palopo
# Processing Record 20 of Set 8 | pendleton
# Processing Record 21 of Set 8 | tetouan
# Processing Record 22 of Set 8 | ixtapa
# Processing Record 23 of Set 8 | homestead meadows north
# Processing Record 24 of Set 8 | uturoa
# Processing Record 25 of Set 8 | alo
# Processing Record 26 of Set 8 | yilan
# Processing Record 27 of Set 8 | bodo
# Processing Record 28 of Set 8 | baicheng
# Processing Record 29 of Set 8 | cicuco
# Processing Record 30 of Set 8 | conceicao da barra
# Processing Record 31 of Set 8 | magadan
# Processing Record 32 of Set 8 | chaihe
# Processing Record 33 of Set 8 | port lincoln
# Processing Record 34 of Set 8 | sombor
# Processing Record 35 of Set 8 | kone
# Processing Record 36 of Set 8 | koulamoutou
# Processing Record 37 of Set 8 | deqen
# Processing Record 38 of Set 8 | tayshet
# Processing Record 39 of Set 8 | cam ranh
# Processing Record 40 of Set 8 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 41 of Set 8 | mae hong son
# Processing Record 42 of Set 8 | kalmunai
# Processing Record 43 of Set 8 | vuktyl
# Processing Record 44 of Set 8 | tarawa
# Processing Record 45 of Set 8 | tralee
# Processing Record 46 of Set 8 | kollegal
# Processing Record 47 of Set 8 | winnemucca
# Processing Record 48 of Set 8 | saint-joseph
# Processing Record 49 of Set 8 | koneurgench
# City not found. Skipping...
# Processing Record 0 of Set 9 | kharp
# Processing Record 1 of Set 9 | taltal
# Processing Record 2 of Set 9 | eisen
# Processing Record 3 of Set 9 | mandera
# Processing Record 4 of Set 9 | argostolion
# Processing Record 5 of Set 9 | kiuruvesi
# Processing Record 6 of Set 9 | kuala belait
# Processing Record 7 of Set 9 | san luis de la loma
# Processing Record 8 of Set 9 | tazacorte
# Processing Record 9 of Set 9 | fort mcmurray
# Processing Record 10 of Set 9 | wenatchee
# Processing Record 11 of Set 9 | salinas de hidalgo
# Processing Record 12 of Set 9 | crane
# Processing Record 13 of Set 9 | ryotsu-minato
# Processing Record 14 of Set 9 | balikesir
# Processing Record 15 of Set 9 | peace river
# Processing Record 16 of Set 9 | aklera
# Processing Record 17 of Set 9 | ilha de mocambique
# Processing Record 18 of Set 9 | angra do heroismo
# Processing Record 19 of Set 9 | port-vila
# Processing Record 20 of Set 9 | businga
# Processing Record 21 of Set 9 | fannuj
# City not found. Skipping...
# Processing Record 22 of Set 9 | port macquarie
# Processing Record 23 of Set 9 | dhar
# Processing Record 24 of Set 9 | rudnyy
# Processing Record 25 of Set 9 | saint-philippe
# Processing Record 26 of Set 9 | mahina
# Processing Record 27 of Set 9 | yamba
# Processing Record 28 of Set 9 | yelizovo
# Processing Record 29 of Set 9 | al kharijah
# Processing Record 30 of Set 9 | ghat
# Processing Record 31 of Set 9 | rouyn-noranda
# Processing Record 32 of Set 9 | alofi
# Processing Record 33 of Set 9 | kedrovyy
# Processing Record 34 of Set 9 | hithadhoo
# Processing Record 35 of Set 9 | shendi
# Processing Record 36 of Set 9 | hamilton
# Processing Record 37 of Set 9 | togur
# Processing Record 38 of Set 9 | sao miguel do araguaia
# Processing Record 39 of Set 9 | alva
# Processing Record 40 of Set 9 | nadym
# Processing Record 41 of Set 9 | susuman
# Processing Record 42 of Set 9 | charef
# Processing Record 43 of Set 9 | galle
# Processing Record 44 of Set 9 | fonadhoo
# City not found. Skipping...
# Processing Record 45 of Set 9 | al jawf
# Processing Record 46 of Set 9 | kismayo
# Processing Record 47 of Set 9 | rapla
# Processing Record 48 of Set 9 | rongelap
# Processing Record 49 of Set 9 | pasighat
# Processing Record 0 of Set 10 | tateyama
# Processing Record 1 of Set 10 | port saint john's
# Processing Record 2 of Set 10 | tot'ma
# Processing Record 3 of Set 10 | neelankarai
# Processing Record 4 of Set 10 | amga
# Processing Record 5 of Set 10 | calama
# Processing Record 6 of Set 10 | orchard homes
# Processing Record 7 of Set 10 | fort bragg
# Processing Record 8 of Set 10 | luanda
# Processing Record 9 of Set 10 | belmonte
# Processing Record 10 of Set 10 | beytussebap
# Processing Record 11 of Set 10 | denia
# Processing Record 12 of Set 10 | port-gentil
# Processing Record 13 of Set 10 | nabire
# Processing Record 14 of Set 10 | upington
# Processing Record 15 of Set 10 | coahuayana de hidalgo
# Processing Record 16 of Set 10 | lamu
# Processing Record 17 of Set 10 | kataba
# Processing Record 18 of Set 10 | la sarre
# Processing Record 19 of Set 10 | hotan
# Processing Record 20 of Set 10 | oued fodda
# Processing Record 21 of Set 10 | ancud
# Processing Record 22 of Set 10 | kaiapoi
# Processing Record 23 of Set 10 | guarapari
# Processing Record 24 of Set 10 | jiaojiang
# Processing Record 25 of Set 10 | wenchang
# Processing Record 26 of Set 10 | hardoi
# Processing Record 27 of Set 10 | agios nikolaos
# Processing Record 28 of Set 10 | puerto lempira
# Processing Record 29 of Set 10 | ribeira brava
# Processing Record 30 of Set 10 | jianshui
# Processing Record 31 of Set 10 | el calafate
# Processing Record 32 of Set 10 | gadzhiyevo
# Processing Record 33 of Set 10 | rio grande
# Processing Record 34 of Set 10 | guaraniacu
# Processing Record 35 of Set 10 | taro
# Processing Record 36 of Set 10 | guozhen
# Processing Record 37 of Set 10 | ban su-ngai pa di
# Processing Record 38 of Set 10 | vicuna mackenna
# Processing Record 39 of Set 10 | kourou
# Processing Record 40 of Set 10 | kaseda-shirakame
# Processing Record 41 of Set 10 | gueltat zemmour
# City not found. Skipping...
# Processing Record 42 of Set 10 | kenosha
# Processing Record 43 of Set 10 | nacala
# Processing Record 44 of Set 10 | dickinson
# Processing Record 45 of Set 10 | kem'
# Processing Record 46 of Set 10 | garbsen-mitte
# Processing Record 47 of Set 10 | fukuecho
# Processing Record 48 of Set 10 | ciudad bolivar
# Processing Record 49 of Set 10 | chengdu
# Processing Record 0 of Set 11 | taroa
# Processing Record 1 of Set 11 | karasuk
# Processing Record 2 of Set 11 | yerofey pavlovich
# Processing Record 3 of Set 11 | merizo village
# Processing Record 4 of Set 11 | higuera de zaragoza
# Processing Record 5 of Set 11 | dubbo
# Processing Record 6 of Set 11 | villa gesell
# Processing Record 7 of Set 11 | lodwar
# Processing Record 8 of Set 11 | majuro
# Processing Record 9 of Set 11 | kletskaya
# Processing Record 10 of Set 11 | nanao
# Processing Record 11 of Set 11 | natal
# Processing Record 12 of Set 11 | spokoynaya
# Processing Record 13 of Set 11 | bunbury
# Processing Record 14 of Set 11 | san julian
# Processing Record 15 of Set 11 | coihueco
# Processing Record 16 of Set 11 | baganga
# Processing Record 17 of Set 11 | xiuyan
# Processing Record 18 of Set 11 | shizuishan
# Processing Record 19 of Set 11 | birjand
# Processing Record 20 of Set 11 | bangor
# Processing Record 21 of Set 11 | greenland
# Processing Record 22 of Set 11 | brokopondo
# Processing Record 23 of Set 11 | uromi
# Processing Record 24 of Set 11 | saudarkrokur
# Processing Record 25 of Set 11 | 'ohonua
# City not found. Skipping...
# Processing Record 26 of Set 11 | shush
# Processing Record 27 of Set 11 | kovdor
# Processing Record 28 of Set 11 | port blair
# Processing Record 29 of Set 11 | gilgit
# Processing Record 30 of Set 11 | cozumel
# Processing Record 31 of Set 11 | mabaruma
# Processing Record 32 of Set 11 | kuta
# Processing Record 33 of Set 11 | floro
# Processing Record 34 of Set 11 | laojunmiao
# Processing Record 35 of Set 11 | farasan
# Processing Record 36 of Set 11 | bulayevo
# Processing Record 37 of Set 11 | panjab
# Processing Record 38 of Set 11 | mount pleasant
# Processing Record 39 of Set 11 | karoi
# Processing Record 40 of Set 11 | gebeit
# Processing Record 41 of Set 11 | ajasse ipo
# Processing Record 42 of Set 11 | pechora
# Processing Record 43 of Set 11 | sao vicente
# Processing Record 44 of Set 11 | kristiansund
# Processing Record 45 of Set 11 | kelaniya
# Processing Record 46 of Set 11 | lospalos
# Processing Record 47 of Set 11 | siracusa
# Processing Record 48 of Set 11 | las vegas
# Processing Record 49 of Set 11 | saint-pierre
# Processing Record 0 of Set 12 | la almunia de dona godina
# Processing Record 1 of Set 12 | chibougamau
# Processing Record 2 of Set 12 | grand falls-windsor
# Processing Record 3 of Set 12 | ar rass
# Processing Record 4 of Set 12 | zhob
# Processing Record 5 of Set 12 | verkh-chebula
# Processing Record 6 of Set 12 | fonte boa
# Processing Record 7 of Set 12 | yadgir
# Processing Record 8 of Set 12 | santa ana
# Processing Record 9 of Set 12 | anibare
# City not found. Skipping...
# Processing Record 10 of Set 12 | viedma

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()

# %%
# Display sample data
city_data_df.head()

# %%
# Convert datetime to readable date format
city_data_df['Date']=(pd.to_datetime(city_data_df['Date'],unit='s')).dt.date
city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', facecolors='g', edgecolors='k')

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature °C")
date=city_data_df['Date'].min()
plt.title(f"City Latitude vs. Temperature ({date})")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind='scatter', x='Lat', y='Humidity', marker='o', grid=True,\
                  facecolors='g', edgecolors='k', title=f'City Latitude vs. Humidity ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind='scatter', x='Lat', y='Cloudiness', marker='o', grid=True,\
                  facecolors='g', edgecolors='k', title=f'City Latitude vs. Cloudiness ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind='scatter', x='Lat', y='Wind Speed', marker='o', grid=True,\
                  facecolors='g', edgecolors='k', title=f'City Latitude vs. Wind Speed ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
north_hemi_df = city_data_df.loc[city_data_df['Lat']>= 0,:]

# Display sample data
north_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
south_hemi_df = city_data_df.loc[city_data_df['Lat']<= 0,:]

# Display sample data
south_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plt.scatter(north_hemi_df['Lat'],north_hemi_df['Max Temp'], marker='o', facecolors='g', edgecolors='k')

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Temperature vs. Latitude in Northern Hemisphere")

# Define a function to create Linear Regression plots
def lr_funcV2(x,y,name,vbl,hemi):
    (slope,intercept,rvalue,pvalue,stderror)=linregress(x,y)
    reg_values= x*slope + intercept
    plt.plot(x,reg_values,color='r')
    plt.title(f'Latitude vs. {vbl} - {hemi}')
    plt.xlabel('Latitude')
    plt.ylabel(vbl)
    line_eq = f'y = {(round(slope,2))}x + {(round(intercept,2))}'
    print(f'Linear equation: {line_eq}')
    plt.savefig(f"output_data/LinearRegresion_{name}.png")
    print(f'The r-value is: {rvalue}')

x = north_hemi_df['Lat']
y = north_hemi_df['Max Temp']
name = 'NH_LatVsMaxTemp'
vbl = 'Maximum Temperature C°'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()

# %%
# Linear regression on Southern Hemisphere
plt.scatter(south_hemi_df['Lat'],south_hemi_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

x = south_hemi_df['Lat']
y = south_hemi_df['Max Temp']
name = 'SH_LatVsMaxTemp'
vbl = 'Maximum Temperature C°'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** The ascent towards the equator is accompanied by a rise in maximum temperatures. Within the Northern Hemisphere, a converse correlation is observed, whereas in the Southern Hemisphere, a direct correlation is evident. A strong connection exists between latitude and the highest recorded temperatures.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(north_hemi_df['Lat'],north_hemi_df['Humidity'], marker='o', facecolors='g', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Northern Hemisphere
x = north_hemi_df['Lat']
y = north_hemi_df['Humidity']
name = 'NH_LatVsHumidity'
vbl = 'Humidity (%)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()

# %%
# Southern Hemisphere
plt.scatter(south_hemi_df['Lat'],south_hemi_df['Humidity'], marker='o', facecolors='g', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Southern Hemisphere
x = south_hemi_df['Lat']
y = south_hemi_df['Humidity']
name = 'SH_LatVsHumidity'
vbl = 'Humidity (%)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:**
# In each hemisphere, the linear equation indicates a subtly positive correlation, suggesting that proximity to the equator does not significantly influence humidity. The available data suggests a minimal or nonexistent connection between latitude and humidity. However, the scatter points illustrate that the data is too widely dispersed to establish a dependable relationship between latitude and humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(north_hemi_df['Lat'],north_hemi_df['Cloudiness'], marker='o', facecolors='g', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Northern Hemisphere
x = north_hemi_df['Lat']
y = north_hemi_df['Cloudiness']
name = 'NH_LatVsCloudiness'
vbl = 'Cloudiness (%)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()

# %%
# Southern Hemisphere
plt.scatter(south_hemi_df['Lat'],south_hemi_df['Cloudiness'], marker='o', facecolors='g', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Southern Hemisphere
x = south_hemi_df['Lat']
y = south_hemi_df['Cloudiness']
name = 'SH_LatVsCloudiness'
vbl = 'Cloudiness (%)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:**
# In each hemisphere, the linear equation demonstrates a positive correlation, indicating that proximity to the equator has no impact on cloudiness. The data available suggests a negligible or absent correlation between latitude and cloudiness. However, the scatter points reveal that the data is too widely dispersed to establish a reliable relationship between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(north_hemi_df['Lat'],north_hemi_df['Wind Speed'], marker='o', facecolors='g', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Northern Hemisphere
x = north_hemi_df['Lat']
y = north_hemi_df['Wind Speed']
name = 'NH_LatVsWindSpeed'
vbl = 'Wind Speed (m/s)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()

# %%
# Southern Hemisphere
plt.scatter(south_hemi_df['Lat'],south_hemi_df['Wind Speed'], marker='o', facecolors='g', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Southern Hemisphere
x = south_hemi_df['Lat']
y = south_hemi_df['Wind Speed']
name = 'SH_LatVsWindSpeed'
vbl = 'Wind Speed (m/s)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:**
# Low r-values are observed for both hemispheres, indicating a minimal or nonexistent connection between latitude and wind speed in the available data. The scatter points illustrate that the data is too widely dispersed to establish any dependable correlation between latitude and wind speed.
