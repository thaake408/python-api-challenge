# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  port elizabeth -33.9180   25.5701     17.40        85           0
# 1        1         chimore -16.9833  -65.1333     24.41        92          77
# 2        2      rio branco  -9.9747  -67.8100     25.34        94         100
# 3        3        bilibino  68.0546  166.4372    -32.67       100         100
# 4        4           aioun  16.6614   -9.6149     19.26        14           0
#
#    Wind Speed Country        Date
# 0        2.57      ZA  2024-01-07
# 1        0.53      BO  2024-01-07
# 2        1.54      BR  2024-01-07
# 3        1.15      RU  2024-01-07
# 4        4.20      MR  2024-01-07

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
plot_1 = city_data_df.hvplot.points(
    'Lng',
    'Lat',
    geo=True, 
    tiles = 'OSM', 
    frame_width = 700, 
    frame_height = 500, 
    color='City',
    alpha= 0.5,
    s='Humidity',
    scale= 0.8)

# Display the map
plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_weather = city_data_df.loc[(city_data_df['Max Temp']<=12)\
                            &(city_data_df['Max Temp']>=0)\
                            &(city_data_df['Cloudiness']<=90)\
                            &(city_data_df['Country']!='US')\
                            &(city_data_df['Country']!='AU')\
                            &(city_data_df['Country']!='IN')\
                            &(city_data_df['Country']!='RU')\
                            &(city_data_df['Country']!='CN')\
                            &(city_data_df['Humidity']<70),:]
print(len(ideal_weather))

# Drop any rows with null values
ideal_weather.dropna()

# Display sample data
ideal_weather.head()
# Out:
# 27
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 50        50         ushuaia -54.8000  -68.3000     11.81        58
# 82        82         al jawf  29.5000   38.7500     10.65        64
# 85        85          ghazni  33.5536   68.4269      0.16        63
# 114      114  miguel ahumada  30.6167 -106.5167      6.28        31
# 147      147    punta arenas -53.1500  -70.9167     11.06        66
#
#      Cloudiness  Wind Speed Country        Date
# 50           20        4.63      AR  2024-01-07
# 82            0        3.69      SA  2024-01-07
# 85           32        1.11      AF  2024-01-07
# 114           0        2.24      MX  2024-01-07
# 147           0       10.80      CL  2024-01-07

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather.iloc[:,[1,8,2,3,5]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name']=''

# Display sample data
hotel_df.head()
# Out:
#                City Country      Lat       Lng  Humidity Hotel Name
# 50          ushuaia      AR -54.8000  -68.3000        58
# 82          al jawf      SA  29.5000   38.7500        64
# 85           ghazni      AF  33.5536   68.4269        63
# 114  miguel ahumada      MX  30.6167 -106.5167        31
# 147    punta arenas      CL -53.1500  -70.9167        66

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {'categories':'accommodation.hotel',\
         'filter':'',\
         'bias':'',\
         'apiKey':geoapify_key,\
         'limit':1}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lon = row['Lng']
    lat = row['Lat']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f'circle:{lon},{lat},{radius}'
    params["bias"] = f'proximity:{lon},{lat}'
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# al jawf - nearest hotel: No hotel found
# ghazni - nearest hotel: No hotel found
# miguel ahumada - nearest hotel: Hotel Mexico
# punta arenas - nearest hotel: Hotel Lacolet
# el sauzal de rodriguez - nearest hotel: Hotel Sausalito
# fuglafjordur - nearest hotel: No hotel found
# bolnisi - nearest hotel: Deutsche Mühle
# barcelona - nearest hotel: Cram
# kutum - nearest hotel: No hotel found
# mhamid - nearest hotel: Hotel Kasbah Azalay
# tiznit - nearest hotel: No hotel found
# zhob - nearest hotel: No hotel found
# nacozari de garcia - nearest hotel: Hotel Nacozari
# al jadid - nearest hotel: فندق البركولي
# sayyan - nearest hotel: No hotel found
# heroica guaymas - nearest hotel: Hotel Playa de Cortéz
# kitimat - nearest hotel: MStar Hotel
# al artawiyah - nearest hotel: No hotel found
# chinju - nearest hotel: 동방관광호텔
# gereshk - nearest hotel: No hotel found
# ceylanpinar - nearest hotel: No hotel found
# al mayadin - nearest hotel: No hotel found
# el abiodh sidi cheikh - nearest hotel: No hotel found
# hasaki - nearest hotel: 大新旅館
# mizdah - nearest hotel: No hotel found
# douz - nearest hotel: Louage station Douz
#                        City Country      Lat       Lng  Humidity  \
# 50                  ushuaia      AR -54.8000  -68.3000        58
# 82                  al jawf      SA  29.5000   38.7500        64
# 85                   ghazni      AF  33.5536   68.4269        63
# 114          miguel ahumada      MX  30.6167 -106.5167        31
# 147            punta arenas      CL -53.1500  -70.9167        66
# 159  el sauzal de rodriguez      MX  31.9000 -116.6833        68
# 226            fuglafjordur      FO  62.2440   -6.8140        67
# 227                 bolnisi      GE  41.4479   44.5384        61
# 233               barcelona      ES  41.3888    2.1590        62
# 315                   kutum      SD  14.2000   24.6667        28
# 322                  mhamid      MA  29.8200   -5.7200        46
# 328                  tiznit      MA  29.5833   -9.5000        66
# 335                    zhob      PK  31.3411   69.4481        54
# 357      nacozari de garcia      MX  30.3742 -109.6908        31
# 361                al jadid      LY  27.0500   14.4000        38
# 375                  sayyan      YE  15.1718   44.3244        61
# 404         heroica guaymas      MX  27.9333 -110.9000        33
# 405                 kitimat      CA  54.0524 -128.6534        65
# 421            al artawiyah      SA  26.5053   45.3444        63
# 463                  chinju      KR  35.1928  128.0847        38
# 470                 gereshk      AF  31.8209   64.5701        56
# 482             ceylanpinar      TR  36.8472   40.0500        60
# 490              al mayadin      SY  35.0209   40.4535        49
# 492   el abiodh sidi cheikh      DZ  32.8930    0.5484        53
# 495                  hasaki      JP  35.7333  140.8333        60
# 532                  mizdah      LY  31.4451   12.9801        50
# 586                    douz      TN  33.4663    9.0203        53
#
#                        Hotel Name
# 50   Apart Hotel Aires del Beagle
# 82                 No hotel found
# 85                 No hotel found
# 114                  Hotel Mexico
# 147                 Hotel Lacolet
# 159               Hotel Sausalito
# 226                No hotel found
# 227                Deutsche Mühle
# 233                          Cram
# 315                No hotel found
# 322           Hotel Kasbah Azalay
# 328                No hotel found
# 335                No hotel found
# 357                Hotel Nacozari
# 361                 فندق البركولي
# 375                No hotel found
# 404         Hotel Playa de Cortéz
# 405                   MStar Hotel
# 421                No hotel found
# 463                        동방관광호텔
# 470                No hotel found
# 482                No hotel found
# 490                No hotel found
# 492                No hotel found
# 495                          大新旅館
# 532                No hotel found
# 586           Louage station Douz

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
plot_4 = hotel_df.hvplot.points('Lng',
            'Lat',
            geo=True, 
            tiles = 'OSM', 
            frame_width = 700, 
            frame_height = 500, 
            color='City',
            alpha=0.6,
            hover=True,
            hover_cols='all',
            use_index=False,
            s='Humidity',
            scale= 1.2)
# Display the map
plot_4
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country,Hotel Name)
